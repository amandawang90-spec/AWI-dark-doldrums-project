# %%
import xarray as xr

ds = xr.open_dataset("atm_reduced_3h_tsr_3h_195001-195001.nc")

print(ds)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/xarray/backends/file_manager.py:199, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     198 try:
# --> 199     file = self._cache[self._key]
#     200 except KeyError:
#
# File /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/lib/python3.9/site-packages/xarray/backends/lru_cache.py:53, in LRUCache.__getitem__(self, key)
#      52 with self._lock:
# ---> 53     value = self._cache[key]
#      54     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/work/ab0995/a270321/AWI-dark-doldrums-project/atm_reduced_3h_tsr_3h_195001-195001.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False))]
#
# ...

# %%
import os

print(os.getcwd())
# Out:
# /work/ab0995/a270321/AWI-dark-doldrums-project

# %%
import os

print(os.getcwd())
print(os.path.exists("atm_reduced_3h_tsr_3h_195001-195001.nc"))
# Out:
# /work/ab0995/a270321/AWI-dark-doldrums-project
# False

# %%
import os
import glob

print(os.getcwd())
print(os.listdir("/work/ab0995/a270321/AWI-dark-doldrums-project")[:20])
print(glob.glob("/work/ab0995/a270321/AWI-dark-doldrums-project/*.nc")[:10])
# Out:
# /work/ab0995/a270321/AWI-dark-doldrums-project
# ['updtim.F90', 'LICENSE', '.git', 'wind', 'updtier.F90', 'dark-doldrum-project-proposal.md', 'README-3.md', 'README.md', 'data_check.ipynb', 'solar', '.gitignore', 'dark-doldrum-project-proposal-update.md']
# []

# %%
import socket
import os
import sys

print("hostname:", socket.gethostname())
print("python:", sys.executable)
print("cwd:", os.getcwd())
# Out:
# hostname: levante0.lvt.dkrz.de
# python: /sw/spack-levante/mambaforge-4.11.0-0-Linux-x86_64-sobz6z/bin/python
# cwd: /work/ab0995/a270321/AWI-dark-doldrums-project

# %%
import subprocess

result = subprocess.run(
    ["ls", "-lh", "/work/ab0995/a270321/AWI-dark-doldrums-project"],
    capture_output=True,
    text=True
)

print(result.stdout)
print(result.stderr)
# Out:
# total 144K
# -rw-r--r-- 1 a270321 ab0995  27K Sep 10 14:38 dark-doldrum-project-proposal.md
# -rw-r--r-- 1 a270321 ab0995  32K Sep 10 16:27 dark-doldrum-project-proposal-update.md
# -rw-r--r-- 1 a270321 ab0995  19K Sep 11 17:22 data_check.ipynb
# -rw-r--r-- 1 a270321 ab0995 1.1K Sep  8 12:57 LICENSE
# -rw-r--r-- 1 a270321 ab0995 1.6K Sep 11 09:44 README-3.md
# -rw-r--r-- 1 a270321 ab0995 4.1K Sep 10 15:34 README.md
# drwxr-sr-x 5 a270321 ab0995 4.0K Sep 11 17:18 solar
# -rw-r--r-- 1 a270321 ab0995 5.4K Sep 11 09:44 updtier.F90
# -rw-r--r-- 1 a270321 ab0995  32K Sep 11 09:44 updtim.F90
# drwxr-sr-x 4 a270321 ab0995 4.0K Sep 10 14:19 wind

# %%
import subprocess

result = subprocess.run(
    ["find", "/work/ab0995/a270321/AWI-dark-doldrums-project",
     "-name", "atm_reduced_3h_tsr_3h_195001-195001.nc"],
    capture_output=True,
    text=True
)

print(result.stdout)

# %%
import xarray as xr

ds = xr.open_dataset(
    "/work/ab0995/ICCP_AWI_hackthon_2025/TCo1279-DART-1950C/outdata/oifs/atm_reduced_3h_tsr_3h_195001-195001.nc"
)

print(ds)
# Out:
# <xarray.Dataset>
# Dimensions:              (cell: 6599680, nvertex: 4, time_counter: 248,
#                           axis_nbounds: 2)
# Coordinates:
#     lat                  (cell) float32 ...
#     lon                  (cell) float32 ...
#     time_instant         (time_counter) datetime64[ns] ...
#   * time_counter         (time_counter) datetime64[ns] 1950-01-01T03:00:00 .....
# Dimensions without coordinates: cell, nvertex, axis_nbounds
# Data variables:
#     bounds_lon           (cell, nvertex) float32 ...
#     bounds_lat           (cell, nvertex) float32 ...
#     time_instant_bounds  (time_counter, axis_nbounds) datetime64[ns] ...
#     time_counter_bounds  (time_counter, axis_nbounds) datetime64[ns] ...
#     tsr                  (time_counter, cell) float32 ...
# Attributes:
#     name:         atm_reduced_3h_tsr_3h
#     description:  ECE4/OIFS 3hourly surface fields
#     title:        ECE4/OIFS 3hourly surface fields
#     Conventions:  CF-1.6
# ...
